# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(42)

# %% [markdown]
# The clerks at the Walgreens on Houston Street have to tell every customer to take the survey that's printed on their receipt. Walgreens knows that only 10% of customers complete the survey. If Walgreens has 618 customers today, what is the likelihood that 70 or more people take the survey?

# %%
# question about a binomial dist

n_trials = 618
p_of_success = .1
survey_taker_dist = stats.binom(n_trials, p_of_success)

survey_taker_dist.sf(69)
# Out:
# 0.15107528710209764

# %%
x_axis = np.arange(0, 200, 2)
y_axis = pd.Series([survey_taker_dist.sf(x) for x in x_axis])
plt.plot(x_axis, y_axis)
plt.show()

# %%
x_axis = np.arange(65, 75, 1)
y_axis = pd.Series([survey_taker_dist.sf(x) for x in x_axis])
plt.plot(x_axis, y_axis)
plt.show()

# %% [markdown]
# Assume that the time it takes to order and eat the burger special at the Esquire is normally distributed with a mean of 40 minutes and a standard deviation of 15 minutes. If it takes 5 minutes to walk from Codeup to the restaurant, what is the likelihood that you can go eat at The Esquire during your lunch hour and not be late back to class?

# %%
# question about eating lunch at esquire

mu = 40     # 40 minutes on average to order and eat
sigma = 15  # 15 min is the std deviation

travel_time = 5*2
lunch_hour = 60

esquire_dist = stats.norm(mu, sigma)

esquire_dist.cdf(lunch_hour - travel_time)
# Out:
# 0.7475074624530771

# %%
x_axis = np.arange(-5, 85, 1)
y_axis = pd.Series([esquire_dist.pdf(x) for x in x_axis])
plt.plot(x_axis, y_axis)
plt.show()
